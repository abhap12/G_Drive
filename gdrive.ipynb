# %%
# import the required libraries
from __future__ import print_function
import pickle
import os.path
import io
import shutil
import requests
from mimetypes import MimeTypes
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from googleapiclient.http import MediaIoBaseDownload, MediaFileUpload
  
class DriveAPI:
    global SCOPES
      
    # Define the scopes
    SCOPES = ['https://www.googleapis.com/auth/drive']
  
    def __init__(self):
        
        # Variable self.creds will
        # store the user access token.
        # If no valid token found
        # we will create one.
        self.creds = None
  
        # The file token.pickle stores the
        # user's access and refresh tokens. It is
        # created automatically when the authorization
        # flow completes for the first time.
  
        # Check if file token.pickle exists
        if os.path.exists('token.pickle'):
  
            # Read the token from the file and
            # store it in the variable self.creds
            with open('token.pickle', 'rb') as token:
                self.creds = pickle.load(token)
  
        # If no valid credentials are available,
        # request the user to log in.
        if not self.creds or not self.creds.valid:
  
            if self.creds and self.creds.expired and self.creds.refresh_token:
                self.creds.refresh(Request())
            else:
                flow = InstalledAppFlow.from_client_secrets_file(
                    'credentials.json', SCOPES)
                self.creds = flow.run_local_server(port=0)
  
            # Save the access token in token.pickle
            # file for future usage
            with open('token.pickle', 'wb') as token:
                pickle.dump(self.creds, token)
  
        # Connect to the API service
        self.service = build('drive', 'v3', credentials=self.creds)
  
        # request a list of first N files or
        # folders with name and id from the API.
        results = self.service.files().list(
            pageSize=100, fields="files(id, name)").execute()
        items = results.get('files', [])
  
        # print a list of files
  
        print("Here's a list of files: \n")
        print(*items, sep="\n", end="\n\n")
  
    def FileDownload(self, file_id, file_name):
        request = self.service.files().get_media(fileId=file_id)
        fh = io.BytesIO()
          
        # Initialise a downloader object to download the file
        downloader = MediaIoBaseDownload(fh, request, chunksize=204800)
        done = False
  
        try:
            # Download the data in chunks
            while not done:
                status, done = downloader.next_chunk()
  
            fh.seek(0)
              
            # Write the received data to the file
            with open(file_name, 'wb') as f:
                shutil.copyfileobj(fh, f)
  
            print("File Downloaded")
            
            return True
        except:
            
            print("Something went wrong.")
            return False
  
    def FileUpload(self, filepath):
        
        # Extract the file name out of the file path
        name = filepath.split('/')[-1]
          
        # Find the MimeType of the file
        mimetype = MimeTypes().guess_type(name)[0]
          
        # create file metadata
        file_metadata = {'name': name}
  
        try:
            media = MediaFileUpload(filepath, mimetype=mimetype)
              
            # Create a new file in the Drive storage
            file = self.service.files().create(
                body=file_metadata, media_body=media, fields='id').execute()
              
            print("File Uploaded.")
          
        except:
              
            raise UploadError("Can't Upload File.")
  
if __name__ == "__main__":
    obj = DriveAPI()
    i = int(input("Enter your choice:1 - Download file, 2- Upload File, 3- Exit.\n"))
      
    if i == 1:
        f_id = input("Enter file id: ")
        f_name = input("Enter file name: ")
        obj.FileDownload(f_id, f_name)
          
    elif i == 2:
        f_path = input("Enter full file path: ")
        obj.FileUpload(f_path)
      
    else:
        exit()
# Out:
# Here's a list of files:
#
# {'id': '1ATgpwog7F9by9BQg-4zjOvjY3YeUywHmvgTyWm6wb44', 'name': 'Covid19 Eyantra'}
# {'id': '1VT8lCtkJMpLLq9xX6RyUjkrZAYAcxu1BYYzye-VHl9I', 'name': 'NEI IDEA FACTORY (TEAM KALAM Survey) (Responses)'}
# {'id': '1nmzIOlzVBKdzPOjq7xR2iwHq3JkJaiuEwJ6WFE_LasA', 'name': 'Nurturelabs Intern Assignment Python/Django'}
# {'id': '1KA62oH9qlADolKf7-p5WxbN69uGyCetRi8kLK1KQowk', 'name': 'Azure hackathon'}
# {'id': '1vbyzpI-ZepP25Nb7L_Nnd4Ntl2rWihvWVs3jGe8P7D4', 'name': 'Abha - Presentation transcript'}
# {'id': '15VR7B_K4NgnCfYb5Xi5NelaxW2LDp7HoXPvtAm-cVws', 'name': 'Using Open Earth Observations For Measuring Economic Indicators'}
# {'id': '1drgBIQ7ioDFG7xZwz8FwPPD-vPYSuHEu', 'name': 'Using Open Earth Observations For Measuring Economic Indicators.pdf'}
# {'id': '1cDnbhdPVh2lRfC_CcXd32xoJ-xOM2Qmm', 'name': 'Using Open Earth Observations For Measuring Economic Indicators.pptx'}
# {'id': '13zUTodS12H0psyT2GT8IF2XzrlgEfHIn', 'name': 'stockiq.ipynb'}
# {'id': '1zPJJgEh2doT5AuM31zlwoIM6JVnwo6pc', 'name': 'gamedata.csv'}
# {'id': '1imhZL_AUOesq6jbX1r8Ez5ibLmedkDAZ', 'name': 'JNID- 12-05-2021-01 - Project Polaris_Persistent Campus Initiative.pdf'}
# {'id': '1WxLNRh-NDEME1-WXVTZlcQSA6bnaJrB1', 'name': 'GameData'}
# {'id': '1ptl3bn7_csBd27YMjrGor07b34HRoTLf', 'name': '0801EC181002_BT_ET_Abha_Porwal.pdf'}
# {'id': '1TMfs__aSROxfcXbHT0ohl7lrCi9e16Is8MSg9qDgonk', 'name': 'Deep Learning CV Hackathon problem statement'}
# {'id': '1mLbfafPmDdXJOxoZ--M1L3KDea8gQmRyjA5kAoHOPGs', 'name': 'gamedata'}
# {'id': '1fHn7_nSZYc2evlHXnhpRQ49l76DZgW2X_u4A2S9oNus', 'name': 'Problem Statement'}
# {'id': '1iGMSY9uYJPCpqPMMZm4-og5e6UqYFXZX', 'name': 'gamedata.csv'}
# {'id': '1PNzOZOmtLgtJDipFW8PFdN_RWR6WsGygXfi48DaTeLg', 'name': 'nqt-srjr-krk - May 6, 2021'}
# {'id': '1HU5EjcgAnTdUUZlAg2HRa1BCL2-zOlTH6muTvtrrZJc', 'name': 'zbj-bmzo-nfa - May 3, 2021'}
# {'id': '17jB-YJAVikVYjzbDEP64RzYnhE77ZzJfo_ElZyTH2Qo', 'name': '6. Guide '}
# {'id': '1XJug-AUYwBykUKM9EoLYpQeaNUs_22e6sbN-9oWurtk', 'name': 'bga-dpay-xwd - Feb 17, 2021'}
# {'id': '1EQ68l90ExukHMj9EMyyaBvAwOssp43h6', 'name': 'C42_PYTHON_BIG_PPT.png'}
# {'id': '1rYf718TeFeOwzF6ZTnAsDNz5ErBDOYPF31SoLk1CDJg', 'name': 'sux-yhag-qvn - May 1, 2021'}
# {'id': '1TW27jCSej16BP7gPrlQNnOlRA9s96gMn', 'name': 'Arpit Verma.pdf'}
# {'id': '116NKfLqFEkI0nyQRPEOpshw3qj_3pXUR', 'name': 'reddit-scrapper-aws-architechture.mp4'}
# {'id': '1LGDswZkV2qBZAbx-TVNruPWs9pcsK-Hh', 'name': 'Coaching Selection.xlsx'}
# {'id': '15I5v6Pg3nVQWOB2V2A8k8mZhFxbnLc9N', 'name': 'Innovaccer - PM_Intern(JD).pdf'}
# {'id': '1dFW6HYs1kTIDUFEx8W_wtqkU8siMr1qqsgQlQbAf3Hg', 'name': 'wye-biid-zvj - Apr 7, 2021'}
# {'id': '1mq06IbnWIJEne_cjD7Y8g8LiesVwiOuSD1fPIJDMDRA', 'name': 'NEI IDEA FACTORY (TEAM KALAM Survey)'}
# {'id': '1ZRIlWKJPliac4O3-048sTLKkchZbc4ulwoRCw_uLd58', 'name': 'quk-ytms-yki - Apr 27, 2021'}
# {'id': '1rejug6Vr5rWsD_ZBtPX7EvLVw385BDhx9NdqhvAio8U', 'name': 'Makkajai Dev Challenge'}
# {'id': '1lLyU9anDB5dxXPnrEMO3w_lxbzwSCLtVnFNwwefV2b4', 'name': 'JD DL CV for AV Internship'}
# {'id': '1a3yHc0bT8TfOQbr7eUsHSBh6oCGOC11kvX4Sl1eAD7A', 'name': '2021 Impact Summits - 3Cs Business Strategy Model'}
# {'id': '1A9G6CSwsVCAlLu5ae64RTpaa91d1SJuR', 'name': 'Vidit Jain.pdf'}
# {'id': '1nNuGTReCea_SWsJUfaVMAMzSzocToBKh', 'name': 'Aniket Kanodiya.pdf'}
# {'id': '150KU2KnpIeN5UMobq0g3mGOsbkYmcY0WMoxFMP3QI6s', 'name': 'Electrothon SRC - CodingBlocks'}
# {'id': '1Kb4reVM7tcIizZ9gkKHh5XzUKf4CCIsF', 'name': 'Susmit Rudra.pdf'}
# {'id': '1JjjeShunXFFz0U1fW1GmdnxLWE6ogSLa', 'name': 'Srishti Porwal.pdf'}
# {'id': '14ajiTDkR1jDF4BIE-3na-zZI2M9f3OoY', 'name': 'Shreyansh Soni.pdf'}
# {'id': '1OsVhx7UnttNFn0QegNdI6m6uVgWhIgIm', 'name': 'Rigved Pandya.pdf'}
# {'id': '1GMkw8vlH4rFa3VGkNNu0KtpTSkRxdlNX', 'name': 'Pradhumn sharma.pdf'}
# {'id': '1FIjl4hA9RZthp6tBMJY_uzpuKN8SeIw1', 'name': 'Manish Hazra.pdf'}
# {'id': '1CCespgjmxJgNfwNm1jjW2m5SLdI3eFh4', 'name': 'Kushagra Ahuja.pdf'}
# {'id': '1v6DLfwAcNm04hQdeYS0MC9tJuLH8-Yk_', 'name': 'Jaidip Dey.pdf'}
# {'id': '10KBjDjpEqHichrXxsCQIdZxDt_m_PBvf', 'name': 'Vedant Anantwar.pdf'}
# {'id': '1CL6e4BugtOB372zvEjkh3NOOhKAqRFp5', 'name': 'Shivam Agharkar.pdf'}
# {'id': '1SEgs4QWT9LUZdMnPsDm2aR-hO2wwTBSo', 'name': 'Rishabh Jain.pdf'}
# {'id': '1w6sti_VbDW2X86WSb89iRQzAoEWyclkV', 'name': 'Palash Tiwari.pdf'}
# {'id': '1YtsL3QK4f5XkhwdxJ7Rw_eRiakwaEa-E', 'name': 'Aryan Tiwari.pdf'}
# {'id': '1jkR0HjBPny0lAUfvqCjhyw7ZE1imPmdY', 'name': 'Purva Gharat.pdf'}
# {'id': '1-S_hK19VgcTBmnYZGz7RTOQ_rLN2ArVU', 'name': 'Aditya Rotithor.pdf'}
# {'id': '1N1BPZpmOEOa3x95QzQAK84qggwL5sQM2', 'name': 'Devesh Jeswani.pdf'}
# {'id': '1LKYBCCmUK1XCNmyvbEKqemA8-kSvQKpw', 'name': 'Aarushi Bhate.pdf'}
# {'id': '1RgMRnhn3z2v6R1CUT41HmJPN4M8sTMEo', 'name': 'certificates'}
# {'id': '1fhvZ4pRQhnPjrkcDvewGGTcphb63dzqd', 'name': 'Abhinav Awasthi.pdf'}
# {'id': '1wY36bHfyyp3bhZhLzBHbTAnSLMJAp62o', 'name': 'Priyanshi Porwal.pdf'}
# {'id': '1q-ei9gzQZj5Y6LwlJBCymYKoWm0fKQxk', 'name': 'Lakshya Sharma.pdf'}
# {'id': '1cU9sB93w3sRsBNeSmjz0clljJQBuFnvQodCpVOgG0ac', 'name': 'Final Results Electrothon2k21'}
# {'id': '1HEKVud3xx8UvLzUsB2sGQVp0fsv_ej-vt1Az2vAqhzQ', 'name': '2021 Impact Summits - Pitch Map'}
# {'id': '1Ij2UD6VML6nCavKv2yHED0rT4E1SB5Ya', 'name': '0801EC181002_BT_ET_Abha_Porwal-1.pdf'}
# {'id': '1TYsh9BbuGuOb_C5ayx5pp1lb9QRTRJF3', 'name': 'sentinel_upscaling.ipynb'}
# {'id': '1gWyN6veSSrzwiTtKWbHBXObmyEHoYTE2hmsm5aFRGFo', 'name': '2021 Impact Summits - Business Model Canvas'}
# {'id': '1K_xRBRDYqSYE-5pk4dJJ2CdNAjBtuYuQ', 'name': 'EDC with OSM.ipynb'}
# {'id': '1D4tGNBfMeeiKl_ILk21Kl_1tIk4anRT0', 'name': 'EC21S43011438  scoreCard.pdf'}
# {'id': '1Z_BVJ7hK5_8FEVeJ43H-KQQzBmwXXcEx', 'name': 'B324Y11ApplicationForm (1).pdf'}
# {'id': '14ro-uWhWp4iG45mRV3h3HcOhmaY6nHYU', 'name': 'B324Y11AdmitCard (1).pdf'}
# {'id': '15S04q9b4O-BFVH55b9xQ3OVYfNGwDNLlwRL5mJdT7ys', 'name': 'SENTINEL_TRUCK_DATA'}
# {'id': '1Fvlkh75itpCM1hYo3i392G2zfL6VyVXr', 'name': 'Screenshot (94).png'}
# {'id': '1LH8JD0Ez-QevU00BcGDesKGxJ8JzlGFB', 'name': 'Screenshot (101).png'}
# {'id': '1Eq1VZdRLuqV6zKTt8fZenYg3Bof8qOBK', 'name': 'Screenshot (108).png'}
# {'id': '1kpbSiePGr3ZIH2rSzXBVGjRsoYiTxGxz', 'name': 'Screenshot (88).png'}
# {'id': '1RqYFE2M1IzbYgJsnNTo85fFtC5RNivpH', 'name': 'Screenshot (98).png'}
# {'id': '1oXqt-F02nFWFFhSSID422vxr7i1w1qUA', 'name': 'Screenshot (103).png'}
# {'id': '17v_6OIMho14lCrfmgz86A81apyK_ERk5', 'name': 'Screenshot (111).png'}
# {'id': '1FJq7tQqbxasPFdxWfiGvCDzq9I2DqpAR', 'name': 'Screenshot (104).png'}
# {'id': '1AWjtPmyowt99UMPJfJkp_heYbCs-ryP3', 'name': 'Screenshot (95).png'}
# {'id': '1CHcncQMlTHh-s88y0QlfKXRsalTipzRu', 'name': 'Screenshot (93).png'}
# {'id': '1qZqLGJYBbvBwbWvPkhZHmlto2SWC81_1', 'name': 'Screenshot (109).png'}
# {'id': '17MwvE-ucCQmtf5uO3GIUvKXAvI-A08Ch', 'name': 'Screenshot (110).png'}
# {'id': '1U3OrSbp4aJJ_DFSQQDzd2d_pK8MzlxfD', 'name': 'Screenshot (96).png'}
# {'id': '1E1kooW1AMUjm4o-c8A1a00kSNAOke_DF', 'name': 'Screenshot (92).png'}
# {'id': '1lDk85UH3JzQVKLHsNq0UmOJwQV7fuDzI', 'name': 'Screenshot (89).png'}
# {'id': '1GQJMTkhHX4ytxCt7ujifCJck8OBL6N0B', 'name': 'Screenshot (107).png'}
# {'id': '1qlKMWARBZNXAKAm29yQtRacTe36uIEZh', 'name': 'Screenshot (90).png'}
# {'id': '1FhVRGmigRD4Fi7BfjV3AvMXvlSMCf09n', 'name': 'Screenshot (105).png'}
# {'id': '1po5XEC2PPL8QjfTavu49uX5aQSaOeUPf', 'name': 'Screenshot (100).png'}
# {'id': '166yapXTDalP-2KM3rqwlTnK9NahbPZqY', 'name': 'Screenshot (102).png'}
# {'id': '11UHDXqKMvxY1LyJ7E1Qv5eaB1VaCwFr4', 'name': 'Screenshot (91).png'}
# {'id': '14VL9lpbJFZiWFFnkz_-jUkTNaWFKsTyM', 'name': 'Screenshot (99).png'}
# {'id': '11EdZfD_MZt85y8LSMvO4xuMJ4d-Cy6y4', 'name': 'Screenshot (112).png'}
# {'id': '15pv56grhRdkXjXs_BWXMgC_cD2l04_AY', 'name': 'Screenshot (97).png'}
# {'id': '11XxrjWYQ3h2nGDu3wAHmxGUL-AUFleAI', 'name': 'Screenshot (106).png'}
# {'id': '1aR6K_ECOrJSSCt7ZhdakLpi95gn2PJ5CVSEu5G4E0TY', 'name': 'ELECTROTHON 2021 FINALS'}
# {'id': '19-cmrwwLknz3w2du0Fip6XTqUt9SoLCyB5gW6GIbyIM', 'name': 'ELECTROTHON 2021 Final Submission'}
# {'id': '1s-_frNdgeU0m67h5MCXT_nbe98L8K0Nn', 'name': 'Indian_loc_truck_covid_19.ipynb'}
# {'id': '1Zp4jHhWPBESCLxrgH4oDMEDiMz9OS6dCLNr_8HXqdh0', 'name': 'SRC workshop'}
# {'id': '11COgypa8T34CpiBeA1nFBvXUss6X8DjH', 'name': 'C42_PYTHON_COTALK.png'}
# {'id': '1ixZdZaLtjsIQQjFUOxfWwZycXztP4K3q', 'name': 'C42_PYTHON_GREEN SCREEN.png'}
# {'id': '1iza1iulFPqAWVYjsMVms1EY3EbxD6LMe', 'name': 'C42_PYTHON_NO_PPT.png'}
# {'id': '1sCPHVMsnFoMLw7Dbsg1bVC7l4zMMfZFz', 'name': 'C42_PYTHON_SMALL_PPT.png'}
